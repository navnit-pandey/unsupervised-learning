# %% [markdown]
# <a href="https://colab.research.google.com/github/navnit-pandey/unsupervised-learning/blob/main/Untitled396_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# k Medoids

# %%
pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit-learn-extra-0.3.0.tar.gz (818 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 12.5 MB/s eta 0:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {"Annual Income": [15,16,17,18,19,60,62,65,67,70],
        "Spending Score": [39,42,45,40,43,70,65,72,68,75]
        }
df = pd.DataFrame(data)
df.head()
# Out:
#    Annual Income  Spending Score
# 0             15              39
# 1             16              42
# 2             17              45
# 3             18              40
# 4             19              43

# %%
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters=2, random_state=42)
model = kmedoids.fit(df)
df['Cluster'] = kmedoids.labels_
print(df)
print("Mediods")
print(df.iloc[kmedoids.medoid_indices_])
# Out:
#    Annual Income  Spending Score  Cluster
# 0             15              39        0
# 1             16              42        0
# 2             17              45        0
# 3             18              40        0
# 4             19              43        0
# 5             60              70        1
# 6             62              65        1
# 7             65              72        1
# 8             67              68        1
# 9             70              75        1
# Mediods
#    Annual Income  Spending Score  Cluster
# 1             16              42        0
# 7             65              72        1
